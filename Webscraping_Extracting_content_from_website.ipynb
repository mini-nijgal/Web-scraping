# %% [markdown]
# <a href="https://colab.research.google.com/github/mini-nijgal/Web-scraping/blob/main/Webscraping_Extracting_content_from_website.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

urlopen = requests.get('http://www.cricbuzz.com/cricket-news/100707/destinys-child-zimbabwes-middle-order-batsman-sikandar-raza-treats-triumphs-and-failures-the-same').text
print(urlopen)
# Out:
# <!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"><head><meta charset="utf-8"><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>html{scroll-behavior: smooth;}	body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-30 {width:30%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb
# ...

# %%
# create beautiful soup object and parse the html so we can use bs methods
#import bs4
bs = bs4.BeautifulSoup(urlopen, 'html.parser')

# %%
import bs4

# %%
title = bs.title
print(title)
# Out:
# <title itemprop="name">Destiny's child, Raza treats triumphs and failures the same | Cricbuzz.com</title>

# %%
title_text = title.getText()
print(title_text)
# Out:
# Destiny's child, Raza treats triumphs and failures the same | Cricbuzz.com

# %%
p_list = bs.find_all('p')
print(p_list)
# Out:
# [<p class="cb-srch-suggest-content-title" ng-bind-html="suggest | searchfilter:oldText"></p>, <p class="cb-srch-suggest-content-subtitle cb-font-12 cb-text-gray">{{suggest.tag}}</p>, <p class="cb-srch-suggest-content-title">Search for “<span ng-bind="searchText"></span>”</p>, <p class="cb-nws-para"> Life - many times - has a curious way of laughing at us. After hours of planning, hours of training and hard work, and repetition, we may fall short of the desired outcome or an unforeseen event could lead us to an unknown path. That is when we usually take solace in the word 'fate' and say, "It was not meant to be. Everything happens for a reason". </p>, <p class="cb-nws-para"> Zimbabwe's middle-order batsman, <a href="/profiles/9354/sikandar-raza">Sikandar Raza</a>, also could have blamed fate and asked himself, "why me" or "what if" after his grand plan to become a fighter Pilot in the PAF (Pakistan Air Force) was cut off abruptly. Raza was a faithful student to his dreams, tirelessly 
# ...

# %%
img_list = bs.find_all('img', height='30')
print(img_list)
# Out:
# []

# %%
p_list = bs.find_all('p', class_ = 'cb-nws-para')
print(p_list)
# Out:
# [<p class="cb-nws-para"> Life - many times - has a curious way of laughing at us. After hours of planning, hours of training and hard work, and repetition, we may fall short of the desired outcome or an unforeseen event could lead us to an unknown path. That is when we usually take solace in the word 'fate' and say, "It was not meant to be. Everything happens for a reason". </p>, <p class="cb-nws-para"> Zimbabwe's middle-order batsman, <a href="/profiles/9354/sikandar-raza">Sikandar Raza</a>, also could have blamed fate and asked himself, "why me" or "what if" after his grand plan to become a fighter Pilot in the PAF (Pakistan Air Force) was cut off abruptly. Raza was a faithful student to his dreams, tirelessly chasing them down in his own workshops. For a while, Raza's faith in his hard work seemed to have reaped rewards, as he passed the exam to enter the Pakistan Air Force School in Lower Topa. Incidentally, he was one of just 60 students who made the cut from thousands of aspira
# ...

# %%
bs.a.get('href')
# Out:
# 'https://plus.google.com/104502282508811467249'

# %%
head_line = bs.find_all('h1', class_='nws-dtl-hdln')

# extracting heading text && assigning it to the content variable
content = head_line[0].getText() + '\n\n'

# extracting paragraphs and concatinating it into content
for p in bs.find_all('section', class_='cb-nws-dtl-itms', itemprop='articleBody'):
    content = content + p.getText().strip() + '\n\n'

# %%
print(content)
# Out:
#  Destiny's child, Raza treats triumphs and failures the same
#
# Life - many times - has a curious way of laughing at us. After hours of planning, hours of training and hard work, and repetition, we may fall short of the desired outcome or an unforeseen event could lead us to an unknown path. That is when we usually take solace in the word 'fate' and say, "It was not meant to be. Everything happens for a reason".
#
# Zimbabwe's middle-order batsman, Sikandar Raza, also could have blamed fate and asked himself, "why me" or "what if" after his grand plan to become a fighter Pilot in the PAF (Pakistan Air Force) was cut off abruptly. Raza was a faithful student to his dreams, tirelessly chasing them down in his own workshops. For a while, Raza's faith in his hard work seemed to have reaped rewards, as he passed the exam to enter the Pakistan Air Force School in Lower Topa. Incidentally, he was one of just 60 students who made the cut from thousands of aspirants.
#
# ...
